# %%
from google.colab import drive
drive.mount('/content/drive')
import os

# Définir le chemin vers ton dossier
folder_path = '/content/drive/MyDrive/Data_ptcloud'

# Vérifier si le chemin est correct
if os.path.isdir(folder_path):
    print("Le dossier existe.")
else:
    print("Le dossier n'existe pas.")
# Out:
# Mounted at /content/drive
# Le dossier existe.

# %%
import os
import pandas as pd
import random

# Directory containing the .txt files
folder_path = '/content/drive/MyDrive/Data_ptcloud'
output_folder_path = 'path_to_output_folder'

# Ensure the output folder exists
os.makedirs(output_folder_path, exist_ok=True)

# Column names
column_names = ['centroid_x', 'centroid_y', 'meanVelocity', 'length', 'width', 'density', 'rcsEq', 'rcsStd', 'track_id', 'label']

# Set Pandas display options to show all columns
pd.set_option('display.max_columns', None)

# List to hold all DataFrames
dataframes = []

# Load all DataFrames from .txt files
for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        file_path = os.path.join(folder_path, file_name)

        # Check if the file is empty
        if os.path.getsize(file_path) == 0:
            os.remove(file_path)
            print(f"Deleted empty file: {file_path}")
            continue  # Skip to the next file

        # Read the file into a DataFrame
        df = pd.read_csv(file_path, header=None, delimiter=',')

        # Check if the DataFrame has the correct number of columns
        if df.shape[1] < len(column_names):
            # If fewer columns, add NaNs to make up the difference
            df = df.reindex(columns=range(len(column_names)))

        # Assign column names
        df.columns = column_names[:df.shape[1]]

        # Add DataFrame to the list
        dataframes.append((file_name, df))

# Shuffle the list of DataFrames
random.shuffle(dataframes)

# Process and save each shuffled DataFrame
for file_name, df in dataframes:
    # Save the processed (and shuffled) data to a new CSV file
    output_file_path = os.path.join(output_folder_path, f"processed_{file_name.replace('.txt', '.csv')}")
    df.to_csv(output_file_path, index=False)

    # Optionally, display the saved DataFrame
    print(f"Processed and saved {file_name} to {output_file_path}")
# Out:
# Processed and saved 01361.txt to path_to_output_folder/processed_01361.csv
# Processed and saved 00778.txt to path_to_output_folder/processed_00778.csv
# Processed and saved 00565.txt to path_to_output_folder/processed_00565.csv
# Processed and saved 00884.txt to path_to_output_folder/processed_00884.csv
# Processed and saved 01678.txt to path_to_output_folder/processed_01678.csv
# Processed and saved 00783.txt to path_to_output_folder/processed_00783.csv
# Processed and saved 01095.txt to path_to_output_folder/processed_01095.csv
# Processed and saved 00498.txt to path_to_output_folder/processed_00498.csv
# Processed and saved 00480.txt to path_to_output_folder/processed_00480.csv
# Processed and saved 00214.txt to path_to_output_folder/processed_00214.csv
# Processed and saved 01948.txt to path_to_output_folder/processed_01948.csv
# Processed and saved 00888.txt to path_to_output_folder/processed_00888.csv
# Processed and saved 00916.txt to path_to_output_folder/processed_00916.csv
# Processed and saved 00148.txt to path_to_output_folder/processed_00148.csv
# Processed and saved 01648.txt to path_to_output_folder/processed_01648.csv
# Processed and saved 00964.txt to path_to_output_folder/processed_00964.csv
# Processed and saved 00198.txt to path_to_output_folder/processed_00198.csv
# Processed and saved 00777.txt to path_to_output_folder/processed_00777.csv
# Processed and saved 00272.txt to path_to_output_folder/processed_00272.csv
# Processed and saved 01653.txt to path_to_output_folder/processed_01653.csv
# Processed and saved 01117.txt to path_to_output_folder/processed_01117.csv
# Processed and saved 00566.txt to path_to_output_folder/processed_00566.csv
# Processed and saved 01224.txt to path_to_output_folder/processed_01224.csv
# Processed and saved 00039.txt to path_to_output_folder/processed_00039.csv
# Processed and saved 00895.txt to path_to_output_folder/processed_00895.csv
# Processed and saved 01501.txt to path_to_output_folder/processed_01501.csv
# Processed and saved 00450.txt to path_to_output_folder/processed_00450.csv
# Processed and saved 01392.txt to path_to_output_folder/processed_01392.csv
# Processed and saved 01483.txt to path_to_output_folder/processed_01483.csv
# Processed and saved 01553.txt to path_to_output_folder/processed_01553.csv
# Processed and saved 01681.txt to path_to_output_folder/processed_01681.csv
# Processed and saved 00319.txt to path_to_output_folder/processed_00319.csv
# Processed and saved 01812.txt to path_to_output_folder/processed_01812.csv
# Processed and saved 01507.txt to path_to_output_folder/processed_01507.csv
# Processed and saved 00285.txt to path_to_output_folder/processed_00285.csv
# Processed and saved 00589.txt to path_to_output_folder/processed_00589.csv
# Processed and saved 01201.txt to path_to_output_folder/processed_01201.csv
# Processed and saved 01481.txt to path_to_output_folder/processed_01481.csv
# Processed and saved 00760.txt to path_to_output_folder/processed_00760.csv
# Processed and saved 00167.txt to path_to_output_folder/processed_00167.csv
# Processed and saved 00953.txt to path_to_output_folder/processed_00953.csv
# Processed and saved 01527.txt to path_to_output_folder/processed_01527.csv
# Processed and saved 00398.txt to path_to_output_folder/processed_00398.csv
# Processed and saved 00173.txt to path_to_output_folder/processed_00173.csv
# Processed and saved 01568.txt to path_to_output_folder/processed_01568.csv
# Processed and saved 00534.txt to path_to_output_folder/processed_00534.csv
# Processed and saved 00045.txt to path_to_output_folder/processed_00045.csv
# Processed and saved 00555.txt to path_to_output_folder/processed_00555.csv
# Processed and saved 01790.txt to path_to_output_folder/processed_01790.csv
# Processed and saved 00740.txt to path_to_output_folder/processed_00740.csv
# Processed and saved 00705.txt to path_to_output_folder/processed_00705.csv
# Processed and saved 00393.txt to path_to_output_folder/processed_00393.csv
# Processed and saved 01809.txt to path_to_output_folder/processed_01809.csv
# Processed and saved 00764.txt to path_to_output_folder/processed_00764.csv
# Processed and saved 01072.txt to path_to_output_folder/processed_01072.csv
# Processed and saved 00716.txt to path_to_output_folder/processed_00716.csv
# Processed and saved 00591.txt to path_to_output_folder/processed_00591.csv
# Processed and saved 00137.txt to path_to_output_folder/processed_00137.csv
# Processed and saved 00022.txt to path_to_output_folder/processed_00022.csv
# Processed and saved 00557.txt to path_to_output_folder/processed_00557.csv
# Processed and saved 01915.txt to path_to_output_folder/processed_01915.csv
# Processed and saved 00239.txt to path_to_output_folder/processed_00239.csv
# Processed and saved 01550.txt to path_to_output_folder/processed_01550.csv
# Processed and saved 00572.txt to path_to_output_folder/processed_00572.csv
# Processed and saved 01421.txt to path_to_output_folder/processed_01421.csv
# Processed and saved 01339.txt to path_to_output_folder/processed_01339.csv
# Processed and saved 01270.txt to path_to_output_folder/processed_01270.csv
# Processed and saved 00283.txt to path_to_output_folder/processed_00283.csv
# Processed and saved 01086.txt to path_to_output_folder/processed_01086.csv
# Processed and saved 00583.txt to path_to_output_folder/processed_00583.csv
# Processed and saved 00986.txt to path_to_output_folder/processed_00986.csv
# Processed and saved 01467.txt to path_to_output_folder/processed_01467.csv
# Processed and saved 00527.txt to path_to_output_folder/processed_00527.csv
# Processed and saved 00917.txt to path_to_output_folder/processed_00917.csv
# Processed and saved 01364.txt to path_to_output_folder/processed_01364.csv
# Processed and saved 00182.txt to path_to_output_folder/processed_00182.csv
# Processed and saved 00604.txt to path_to_output_folder/processed_00604.csv
# Processed and saved 00008.txt to path_to_output_folder/processed_00008.csv
# Processed and saved 01396.txt to path_to_output_folder/processed_01396.csv
# Processed and saved 01830.txt to path_to_output_folder/processed_01830.csv
# Processed and saved 01345.txt to path_to_output_folder/processed_01345.csv
# Processed and saved 00592.txt to path_to_output_folder/processed_00592.csv
# Processed and saved 00579.txt to path_to_output_folder/processed_00579.csv
# Processed and saved 00587.txt to path_to_output_folder/processed_00587.csv
# Processed and saved 00334.txt to path_to_output_folder/processed_00334.csv
# Processed and saved 01052.txt to path_to_output_folder/processed_01052.csv
# Processed and saved 00465.txt to path_to_output_folder/processed_00465.csv
# Processed and saved 00671.txt to path_to_output_folder/processed_00671.csv
# Processed and saved 00048.txt to path_to_output_folder/processed_00048.csv
# Processed and saved 00605.txt to path_to_output_folder/processed_00605.csv
# Processed and saved 01499.txt to path_to_output_folder/processed_01499.csv
# Processed and saved 00422.txt to path_to_output_folder/processed_00422.csv
# Processed and saved 01674.txt to path_to_output_folder/processed_01674.csv
# Processed and saved 00897.txt to path_to_output_folder/processed_00897.csv
# Processed and saved 01689.txt to path_to_output_folder/processed_01689.csv
# Processed and saved 01058.txt to path_to_output_folder/processed_01058.csv
# Processed and saved 00887.txt to path_to_output_folder/processed_00887.csv
# Processed and saved 01716.txt to path_to_output_folder/processed_01716.csv
# Processed and saved 00185.txt to path_to_output_folder/processed_00185.csv
# Processed and saved 01057.txt to path_to_output_folder/processed_01057.csv
# Processed and saved 01774.txt to path_to_output_folder/processed_01774.csv
# Processed and saved 00253.txt to path_to_output_folder/processed_00253.csv
# Processed and saved 01791.txt to path_to_output_folder/processed_01791.csv
# Processed and saved 00493.txt to path_to_output_folder/processed_00493.csv
# Processed and saved 01551.txt to path_to_output_folder/processed_01551.csv
# Processed and saved 00359.txt to path_to_output_folder/processed_00359.csv
# Processed and saved 00403.txt to path_to_output_folder/processed_00403.csv
# Processed and saved 00222.txt to path_to_output_folder/processed_00222.csv
# Processed and saved 01232.txt to path_to_output_folder/processed_01232.csv
# Processed and saved 00364.txt to path_to_output_folder/processed_00364.csv
# Processed and saved 01765.txt to path_to_output_folder/processed_01765.csv
# Processed and saved 00990.txt to path_to_output_folder/processed_00990.csv
# Processed and saved 00653.txt to path_to_output_folder/processed_00653.csv
# Processed and saved 01422.txt to path_to_output_folder/processed_01422.csv
# Processed and saved 01014.txt to path_to_output_folder/processed_01014.csv
# Processed and saved 01148.txt to path_to_output_folder/processed_01148.csv
# Processed and saved 00407.txt to path_to_output_folder/processed_00407.csv
# Processed and saved 01566.txt to path_to_output_folder/processed_01566.csv
# Processed and saved 01329.txt to path_to_output_folder/processed_01329.csv
# Processed and saved 01494.txt to path_to_output_folder/processed_01494.csv
# Processed and saved 00475.txt to path_to_output_folder/processed_00475.csv
# Processed and saved 01938.txt to path_to_output_folder/processed_01938.csv
# Processed and saved 00429.txt to path_to_output_folder/processed_00429.csv
# Processed and saved 01949.txt to path_to_output_folder/processed_01949.csv
# Processed and saved 00729.txt to path_to_output_folder/processed_00729.csv
# Processed and saved 01197.txt to path_to_output_folder/processed_01197.csv
# Processed and saved 01100.txt to path_to_output_folder/processed_01100.csv
# Processed and saved 00420.txt to path_to_output_folder/processed_00420.csv
# Processed and saved 00310.txt to path_to_output_folder/processed_00310.csv
# Processed and saved 00301.txt to path_to_output_folder/processed_00301.csv
# Processed and saved 01277.txt to path_to_output_folder/processed_01277.csv
# Processed and saved 00879.txt to path_to_output_folder/processed_00879.csv
# Processed and saved 00573.txt to path_to_output_folder/processed_00573.csv
# Processed and saved 00523.txt to path_to_output_folder/processed_00523.csv
# Processed and saved 01064.txt to path_to_output_folder/processed_01064.csv
# Processed and saved 00520.txt to path_to_output_folder/processed_00520.csv
# Processed and saved 00727.txt to path_to_output_folder/processed_00727.csv
# Processed and saved 00467.txt to path_to_output_folder/processed_00467.csv
# Processed and saved 00192.txt to path_to_output_folder/processed_00192.csv
# Processed and saved 00886.txt to path_to_output_folder/processed_00886.csv
# Processed and saved 01142.txt to path_to_output_folder/processed_01142.csv
# Processed and saved 00826.txt to path_to_output_folder/processed_00826.csv
# Processed and saved 00857.txt to path_to_output_folder/processed_00857.csv
# Processed and saved 00328.txt to path_to_output_folder/processed_00328.csv
# Processed and saved 01532.txt to path_to_output_folder/processed_01532.csv
# Processed and saved 00775.txt to path_to_output_folder/processed_00775.csv
# Processed and saved 01319.txt to path_to_output_folder/processed_01319.csv
# Processed and saved 00853.txt to path_to_output_folder/processed_00853.csv
# Processed and saved 01473.txt to path_to_output_folder/processed_01473.csv
# Processed and saved 00558.txt to path_to_output_folder/processed_00558.csv
# Processed and saved 00739.txt to path_to_output_folder/processed_00739.csv
# Processed and saved 00152.txt to path_to_output_folder/processed_00152.csv
# Processed and saved 00516.txt to path_to_output_folder/processed_00516.csv
# Processed and saved 01132.txt to path_to_output_folder/processed_01132.csv
# Processed and saved 00973.txt to path_to_output_folder/processed_00973.csv
# Processed and saved 01417.txt to path_to_output_folder/processed_01417.csv
# Processed and saved 00637.txt to path_to_output_folder/processed_00637.csv
# Processed and saved 00023.txt to path_to_output_folder/processed_00023.csv
# Processed and saved 01073.txt to path_to_output_folder/processed_01073.csv
# Processed and saved 01492.txt to path_to_output_folder/processed_01492.csv
# Processed and saved 01039.txt to path_to_output_folder/processed_01039.csv
# Processed and saved 00256.txt to path_to_output_folder/processed_00256.csv
# Processed and saved 01821.txt to path_to_output_folder/processed_01821.csv
# Processed and saved 01504.txt to path_to_output_folder/processed_01504.csv
# Processed and saved 00501.txt to path_to_output_folder/processed_00501.csv
# Processed and saved 00875.txt to path_to_output_folder/processed_00875.csv
# Processed and saved 01207.txt to path_to_output_folder/processed_01207.csv
# Processed and saved 00278.txt to path_to_output_folder/processed_00278.csv
# Processed and saved 00203.txt to path_to_output_folder/processed_00203.csv
# Processed and saved 01126.txt to path_to_output_folder/processed_01126.csv
# Processed and saved 00390.txt to path_to_output_folder/processed_00390.csv
# Processed and saved 00816.txt to path_to_output_folder/processed_00816.csv
# Processed and saved 01443.txt to path_to_output_folder/processed_01443.csv
# Processed and saved 01526.txt to path_to_output_folder/processed_01526.csv
# Processed and saved 00270.txt to path_to_output_folder/processed_00270.csv
# Processed and saved 01599.txt to path_to_output_folder/processed_01599.csv
# Processed and saved 00518.txt to path_to_output_folder/processed_00518.csv
# Processed and saved 00536.txt to path_to_output_folder/processed_00536.csv
# Processed and saved 01096.txt to path_to_output_folder/processed_01096.csv
# Processed and saved 00491.txt to path_to_output_folder/processed_00491.csv
# Processed and saved 00660.txt to path_to_output_folder/processed_00660.csv
# Processed and saved 00350.txt to path_to_output_folder/processed_00350.csv
# Processed and saved 00817.txt to path_to_output_folder/processed_00817.csv
# Processed and saved 01265.txt to path_to_output_folder/processed_01265.csv
# Processed and saved 01365.txt to path_to_output_folder/processed_01365.csv
# Processed and saved 01851.txt to path_to_output_folder/processed_01851.csv
# Processed and saved 01238.txt to path_to_output_folder/processed_01238.csv
# Processed and saved 01106.txt to path_to_output_folder/processed_01106.csv
# Processed and saved 00858.txt to path_to_output_folder/processed_00858.csv
# Processed and saved 01633.txt to path_to_output_folder/processed_01633.csv
# Processed and saved 00550.txt to path_to_output_folder/processed_00550.csv
# Processed and saved 00155.txt to path_to_output_folder/processed_00155.csv
# Processed and saved 01487.txt to path_to_output_folder/processed_01487.csv
# Processed and saved 00481.txt to path_to_output_folder/processed_00481.csv
# Processed and saved 00644.txt to path_to_output_folder/processed_00644.csv
# Processed and saved 01439.txt to path_to_output_folder/processed_01439.csv
# Processed and saved 00037.txt to path_to_output_folder/processed_00037.csv
# Processed and saved 01849.txt to path_to_output_folder/processed_01849.csv
# Processed and saved 01795.txt to path_to_output_folder/processed_01795.csv
# Processed and saved 00620.txt to path_to_output_folder/processed_00620.csv
# Processed and saved 00311.txt to path_to_output_folder/processed_00311.csv
# Processed and saved 00818.txt to path_to_output_folder/processed_00818.csv
# Processed and saved 00241.txt to path_to_output_folder/processed_00241.csv
# Processed and saved 00474.txt to path_to_output_folder/processed_00474.csv
# Processed and saved 00119.txt to path_to_output_folder/processed_00119.csv
# Processed and saved 00126.txt to path_to_output_folder/processed_00126.csv
# Processed and saved 00195.txt to path_to_output_folder/processed_00195.csv
# Processed and saved 00634.txt to path_to_output_folder/processed_00634.csv
# Processed and saved 01322.txt to path_to_output_folder/processed_01322.csv
# Processed and saved 01020.txt to path_to_output_folder/processed_01020.csv
# Processed and saved 00370.txt to path_to_output_folder/processed_00370.csv
# Processed and saved 01724.txt to path_to_output_folder/processed_01724.csv
# Processed and saved 01897.txt to path_to_output_folder/processed_01897.csv
# Processed and saved 01684.txt to path_to_output_folder/processed_01684.csv
# Processed and saved 01018.txt to path_to_output_folder/processed_01018.csv
# Processed and saved 00874.txt to path_to_output_folder/processed_00874.csv
# Processed and saved 01239.txt to path_to_output_folder/processed_01239.csv
# Processed and saved 00515.txt to path_to_output_folder/processed_00515.csv
# Processed and saved 01602.txt to path_to_output_folder/processed_01602.csv
# Processed and saved 00147.txt to path_to_output_folder/processed_00147.csv
# Processed and saved 01341.txt to path_to_output_folder/processed_01341.csv
# Processed and saved 01295.txt to path_to_output_folder/processed_01295.csv
# Processed and saved 01864.txt to path_to_output_folder/processed_01864.csv
# Processed and saved 00809.txt to path_to_output_folder/processed_00809.csv
# Processed and saved 00372.txt to path_to_output_folder/processed_00372.csv
# Processed and saved 00554.txt to path_to_output_folder/processed_00554.csv
# Processed and saved 00547.txt to path_to_output_folder/processed_00547.csv
# Processed and saved 01146.txt to path_to_output_folder/processed_01146.csv
# Processed and saved 00231.txt to path_to_output_folder/processed_00231.csv
# Processed and saved 00496.txt to path_to_output_folder/processed_00496.csv
# Processed and saved 00356.txt to path_to_output_folder/processed_00356.csv
# Processed and saved 00553.txt to path_to_output_folder/processed_00553.csv
# Processed and saved 01273.txt to path_to_output_folder/processed_01273.csv
# Processed and saved 01160.txt to path_to_output_folder/processed_01160.csv
# Processed and saved 01554.txt to path_to_output_folder/processed_01554.csv
# Processed and saved 01236.txt to path_to_output_folder/processed_01236.csv
# Processed and saved 01732.txt to path_to_output_folder/processed_01732.csv
# Processed and saved 00035.txt to path_to_output_folder/processed_00035.csv
# Processed and saved 00104.txt to path_to_output_folder/processed_00104.csv
# Processed and saved 01529.txt to path_to_output_folder/processed_01529.csv
# Processed and saved 00684.txt to path_to_output_folder/processed_00684.csv
# Processed and saved 00318.txt to path_to_output_folder/processed_00318.csv
# Processed and saved 00180.txt to path_to_output_folder/processed_00180.csv
# Processed and saved 00320.txt to path_to_output_folder/processed_00320.csv
# Processed and saved 01835.txt to path_to_output_folder/processed_01835.csv
# Processed and saved 00603.txt to path_to_output_folder/processed_00603.csv
# Processed and saved 01006.txt to path_to_output_folder/processed_01006.csv
# Processed and saved 01562.txt to path_to_output_folder/processed_01562.csv
# Processed and saved 01205.txt to path_to_output_folder/processed_01205.csv
# Processed and saved 00601.txt to path_to_output_folder/processed_00601.csv
# Processed and saved 00296.txt to path_to_output_folder/processed_00296.csv
# Processed and saved 00673.txt to path_to_output_folder/processed_00673.csv
# Processed and saved 00597.txt to path_to_output_folder/processed_00597.csv
# Processed and saved 00900.txt to path_to_output_folder/processed_00900.csv
# Processed and saved 00386.txt to path_to_output_folder/processed_00386.csv
# Processed and saved 01374.txt to path_to_output_folder/processed_01374.csv
# Processed and saved 00212.txt to path_to_output_folder/processed_00212.csv
# Processed and saved 00977.txt to path_to_output_folder/processed_00977.csv
# Processed and saved 00901.txt to path_to_output_folder/processed_00901.csv
# Processed and saved 01227.txt to path_to_output_folder/processed_01227.csv
# Processed and saved 01366.txt to path_to_output_folder/processed_01366.csv
# Processed and saved 01375.txt to path_to_output_folder/processed_01375.csv
# Processed and saved 00456.txt to path_to_output_folder/processed_00456.csv
# Processed and saved 01751.txt to path_to_output_folder/processed_01751.csv
# Processed and saved 00304.txt to path_to_output_folder/processed_00304.csv
# Processed and saved 00434.txt to path_to_output_folder/processed_00434.csv
# Processed and saved 00682.txt to path_to_output_folder/processed_00682.csv
# Processed and saved 00933.txt to path_to_output_folder/processed_00933.csv
# Processed and saved 00461.txt to path_to_output_folder/processed_00461.csv
# Processed and saved 01274.txt to path_to_output_folder/processed_01274.csv
# Processed and saved 01141.txt to path_to_output_folder/processed_01141.csv
# Processed and saved 00269.txt to path_to_output_folder/processed_00269.csv
# Processed and saved 00815.txt to path_to_output_folder/processed_00815.csv
# Processed and saved 00700.txt to path_to_output_folder/processed_00700.csv
# Processed and saved 01739.txt to path_to_output_folder/processed_01739.csv
# Processed and saved 00512.txt to path_to_output_folder/processed_00512.csv
# Processed and saved 00714.txt to path_to_output_folder/processed_00714.csv
# Processed and saved 00539.txt to path_to_output_folder/processed_00539.csv
# Processed and saved 00931.txt to path_to_output_folder/processed_00931.csv
# Processed and saved 01816.txt to path_to_output_folder/processed_01816.csv
# Processed and saved 00500.txt to path_to_output_folder/processed_00500.csv
# Processed and saved 00966.txt to path_to_output_folder/processed_00966.csv
# Processed and saved 01358.txt to path_to_output_folder/processed_01358.csv
# Processed and saved 01742.txt to path_to_output_folder/processed_01742.csv
# Processed and saved 01080.txt to path_to_output_folder/processed_01080.csv
# Processed and saved 00686.txt to path_to_output_folder/processed_00686.csv
# Processed and saved 01168.txt to path_to_output_folder/processed_01168.csv
# Processed and saved 00117.txt to path_to_output_folder/processed_00117.csv
# Processed and saved 00741.txt to path_to_output_folder/processed_00741.csv
# Processed and saved 00120.txt to path_to_output_folder/processed_00120.csv
# Processed and saved 00294.txt to path_to_output_folder/processed_00294.csv
# Processed and saved 00274.txt to path_to_output_folder/processed_00274.csv
# Processed and saved 00731.txt to path_to_output_folder/processed_00731.csv
# Processed and saved 00384.txt to path_to_output_folder/processed_00384.csv
# Processed and saved 01323.txt to path_to_output_folder/processed_01323.csv
# Processed and saved 00447.txt to path_to_output_folder/processed_00447.csv
# Processed and saved 01150.txt to path_to_output_folder/processed_01150.csv
# Processed and saved 01013.txt to path_to_output_folder/processed_01013.csv
# Processed and saved 01276.txt to path_to_output_folder/processed_01276.csv
# Processed and saved 00362.txt to path_to_output_folder/processed_00362.csv
# Processed and saved 01263.txt to path_to_output_folder/processed_01263.csv
# Processed and saved 01882.txt to path_to_output_folder/processed_01882.csv
# Processed and saved 00080.txt to path_to_output_folder/processed_00080.csv
# Processed and saved 00482.txt to path_to_output_folder/processed_00482.csv
# Processed and saved 01260.txt to path_to_output_folder/processed_01260.csv
# Processed and saved 01839.txt to path_to_output_folder/processed_01839.csv
# Processed and saved 00865.txt to path_to_output_folder/processed_00865.csv
# Processed and saved 01608.txt to path_to_output_folder/processed_01608.csv
# Processed and saved 00108.txt to path_to_output_folder/processed_00108.csv
# Processed and saved 00646.txt to path_to_output_folder/processed_00646.csv
# Processed and saved 00712.txt to path_to_output_folder/processed_00712.csv
# Processed and saved 00220.txt to path_to_output_folder/processed_00220.csv
# Processed and saved 01784.txt to path_to_output_folder/processed_01784.csv
# Processed and saved 00767.txt to path_to_output_folder/processed_00767.csv
# Processed and saved 00930.txt to path_to_output_folder/processed_00930.csv
# Processed and saved 00918.txt to path_to_output_folder/processed_00918.csv
# Processed and saved 00808.txt to path_to_output_folder/processed_00808.csv
# Processed and saved 01748.txt to path_to_output_folder/processed_01748.csv
# Processed and saved 01856.txt to path_to_output_folder/processed_01856.csv
# Processed and saved 01577.txt to path_to_output_folder/processed_01577.csv
# Processed and saved 00785.txt to path_to_output_folder/processed_00785.csv
# Processed and saved 00298.txt to path_to_output_folder/processed_00298.csv
# Processed and saved 01434.txt to path_to_output_folder/processed_01434.csv
# Processed and saved 01368.txt to path_to_output_folder/processed_01368.csv
# Processed and saved 00894.txt to path_to_output_folder/processed_00894.csv
# Processed and saved 01089.txt to path_to_output_folder/processed_01089.csv
# Processed and saved 01149.txt to path_to_output_folder/processed_01149.csv
# Processed and saved 00991.txt to path_to_output_folder/processed_00991.csv
# Processed and saved 01703.txt to path_to_output_folder/processed_01703.csv
# Processed and saved 01409.txt to path_to_output_folder/processed_01409.csv
# Processed and saved 00871.txt to path_to_output_folder/processed_00871.csv
# Processed and saved 01951.txt to path_to_output_folder/processed_01951.csv
# Processed and saved 01628.txt to path_to_output_folder/processed_01628.csv
# Processed and saved 01715.txt to path_to_output_folder/processed_01715.csv
# Processed and saved 01204.txt to path_to_output_folder/processed_01204.csv
# Processed and saved 01004.txt to path_to_output_folder/processed_01004.csv
# Processed and saved 00654.txt to path_to_output_folder/processed_00654.csv
# Processed and saved 00975.txt to path_to_output_folder/processed_00975.csv
# Processed and saved 01493.txt to path_to_output_folder/processed_01493.csv
# Processed and saved 00325.txt to path_to_output_folder/processed_00325.csv
# Processed and saved 00012.txt to path_to_output_folder/processed_00012.csv
# Processed and saved 00305.txt to path_to_output_folder/processed_00305.csv
# Processed and saved 00281.txt to path_to_output_folder/processed_00281.csv
# Processed and saved 00920.txt to path_to_output_folder/processed_00920.csv
# Processed and saved 01538.txt to path_to_output_folder/processed_01538.csv
# Processed and saved 01128.txt to path_to_output_folder/processed_01128.csv
# Processed and saved 00881.txt to path_to_output_folder/processed_00881.csv
# Processed and saved 00827.txt to path_to_output_folder/processed_00827.csv
# Processed and saved 01463.txt to path_to_output_folder/processed_01463.csv
# Processed and saved 01485.txt to path_to_output_folder/processed_01485.csv
# Processed and saved 01087.txt to path_to_output_folder/processed_01087.csv
# Processed and saved 00854.txt to path_to_output_folder/processed_00854.csv
# Processed and saved 01284.txt to path_to_output_folder/processed_01284.csv
# Processed and saved 00980.txt to path_to_output_folder/processed_00980.csv
# Processed and saved 00462.txt to path_to_output_folder/processed_00462.csv
# Processed and saved 01625.txt to path_to_output_folder/processed_01625.csv
# Processed and saved 01637.txt to path_to_output_folder/processed_01637.csv
# Processed and saved 00070.txt to path_to_output_folder/processed_00070.csv
# Processed and saved 01333.txt to path_to_output_folder/processed_01333.csv
# Processed and saved 01403.txt to path_to_output_folder/processed_01403.csv
# Processed and saved 01607.txt to path_to_output_folder/processed_01607.csv
# Processed and saved 00616.txt to path_to_output_folder/processed_00616.csv
# Processed and saved 00522.txt to path_to_output_folder/processed_00522.csv
# Processed and saved 00351.txt to path_to_output_folder/processed_00351.csv
# Processed and saved 00939.txt to path_to_output_folder/processed_00939.csv
# Processed and saved 00353.txt to path_to_output_folder/processed_00353.csv
# Processed and saved 01401.txt to path_to_output_folder/processed_01401.csv
# Processed and saved 01806.txt to path_to_output_folder/processed_01806.csv
# Processed and saved 00315.txt to path_to_output_folder/processed_00315.csv
# Processed and saved 00141.txt to path_to_output_folder/processed_00141.csv
# Processed and saved 01783.txt to path_to_output_folder/processed_01783.csv
# Processed and saved 00780.txt to path_to_output_folder/processed_00780.csv
# Processed and saved 01040.txt to path_to_output_folder/processed_01040.csv
# Processed and saved 00439.txt to path_to_output_folder/processed_00439.csv
# Processed and saved 00867.txt to path_to_output_folder/processed_00867.csv
# Processed and saved 01210.txt to path_to_output_folder/processed_01210.csv
# Processed and saved 01600.txt to path_to_output_folder/processed_01600.csv
# Processed and saved 00211.txt to path_to_output_folder/processed_00211.csv
# Processed and saved 00878.txt to path_to_output_folder/processed_00878.csv
# Processed and saved 00053.txt to path_to_output_folder/processed_00053.csv
# Processed and saved 00228.txt to path_to_output_folder/processed_00228.csv
# Processed and saved 00532.txt to path_to_output_folder/processed_00532.csv
# Processed and saved 01363.txt to path_to_output_folder/processed_01363.csv
# Processed and saved 01709.txt to path_to_output_folder/processed_01709.csv
# Processed and saved 00679.txt to path_to_output_folder/processed_00679.csv
# Processed and saved 00994.txt to path_to_output_folder/processed_00994.csv
# Processed and saved 01921.txt to path_to_output_folder/processed_01921.csv
# Processed and saved 00880.txt to path_to_output_folder/processed_00880.csv
# Processed and saved 01570.txt to path_to_output_folder/processed_01570.csv
# Processed and saved 00845.txt to path_to_output_folder/processed_00845.csv
# Processed and saved 01530.txt to path_to_output_folder/processed_01530.csv
# Processed and saved 01664.txt to path_to_output_folder/processed_01664.csv
# Processed and saved 00564.txt to path_to_output_folder/processed_00564.csv
# Processed and saved 00169.txt to path_to_output_folder/processed_00169.csv
# Processed and saved 01195.txt to path_to_output_folder/processed_01195.csv
# Processed and saved 01123.txt to path_to_output_folder/processed_01123.csv
# Processed and saved 00077.txt to path_to_output_folder/processed_00077.csv
# Processed and saved 01444.txt to path_to_output_folder/processed_01444.csv
# Processed and saved 00667.txt to path_to_output_folder/processed_00667.csv
# Processed and saved 00832.txt to path_to_output_folder/processed_00832.csv
# Processed and saved 00111.txt to path_to_output_folder/processed_00111.csv
# Processed and saved 01908.txt to path_to_output_folder/processed_01908.csv
# Processed and saved 00431.txt to path_to_output_folder/processed_00431.csv
# Processed and saved 00060.txt to path_to_output_folder/processed_00060.csv
# Processed and saved 00099.txt to path_to_output_folder/processed_00099.csv
# Processed and saved 00034.txt to path_to_output_folder/processed_00034.csv
# Processed and saved 01471.txt to path_to_output_folder/processed_01471.csv
# Processed and saved 01910 (1).txt to path_to_output_folder/processed_01910 (1).csv
# Processed and saved 01145.txt to path_to_output_folder/processed_01145.csv
# Processed and saved 00276.txt to path_to_output_folder/processed_00276.csv
# Processed and saved 01065.txt to path_to_output_folder/processed_01065.csv
# Processed and saved 00344.txt to path_to_output_folder/processed_00344.csv
# Processed and saved 00282.txt to path_to_output_folder/processed_00282.csv
# Processed and saved 00995.txt to path_to_output_folder/processed_00995.csv
# Processed and saved 00630.txt to path_to_output_folder/processed_00630.csv
# Processed and saved 00457.txt to path_to_output_folder/processed_00457.csv
# Processed and saved 01221.txt to path_to_output_folder/processed_01221.csv
# Processed and saved 00963.txt to path_to_output_folder/processed_00963.csv
# Processed and saved 01819.txt to path_to_output_folder/processed_01819.csv
# Processed and saved 00922.txt to path_to_output_folder/processed_00922.csv
# Processed and saved 01092.txt to path_to_output_folder/processed_01092.csv
# Processed and saved 00576.txt to path_to_output_folder/processed_00576.csv
# Processed and saved 01665.txt to path_to_output_folder/processed_01665.csv
# Processed and saved 01796.txt to path_to_output_folder/processed_01796.csv
# Processed and saved 01111.txt to path_to_output_folder/processed_01111.csv
# Processed and saved 00989.txt to path_to_output_folder/processed_00989.csv
# Processed and saved 01944.txt to path_to_output_folder/processed_01944.csv
# Processed and saved 01184.txt to path_to_output_folder/processed_01184.csv
# Processed and saved 00004.txt to path_to_output_folder/processed_00004.csv
# Processed and saved 00610.txt to path_to_output_folder/processed_00610.csv
# Processed and saved 01476.txt to path_to_output_folder/processed_01476.csv
# Processed and saved 00308.txt to path_to_output_folder/processed_00308.csv
# Processed and saved 01725.txt to path_to_output_folder/processed_01725.csv
# Processed and saved 01398.txt to path_to_output_folder/processed_01398.csv
# Processed and saved 01815.txt to path_to_output_folder/processed_01815.csv
# Processed and saved 00967.txt to path_to_output_folder/processed_00967.csv
# Processed and saved 01900.txt to path_to_output_folder/processed_01900.csv
# Processed and saved 00194.txt to path_to_output_folder/processed_00194.csv
# Processed and saved 01019.txt to path_to_output_folder/processed_01019.csv
# Processed and saved 01880.txt to path_to_output_folder/processed_01880.csv
# Processed and saved 00950.txt to path_to_output_folder/processed_00950.csv
# Processed and saved 00419.txt to path_to_output_folder/processed_00419.csv
# Processed and saved 00488.txt to path_to_output_folder/processed_00488.csv
# Processed and saved 00413.txt to path_to_output_folder/processed_00413.csv
# Processed and saved 01084.txt to path_to_output_folder/processed_01084.csv
# Processed and saved 00567.txt to path_to_output_folder/processed_00567.csv
# Processed and saved 00122.txt to path_to_output_folder/processed_00122.csv
# Processed and saved 01243.txt to path_to_output_folder/processed_01243.csv
# Processed and saved 01454.txt to path_to_output_folder/processed_01454.csv
# Processed and saved 01410.txt to path_to_output_folder/processed_01410.csv
# Processed and saved 01048.txt to path_to_output_folder/processed_01048.csv
# Processed and saved 00127.txt to path_to_output_folder/processed_00127.csv
# Processed and saved 01135.txt to path_to_output_folder/processed_01135.csv
# Processed and saved 01525.txt to path_to_output_folder/processed_01525.csv
# Processed and saved 01590.txt to path_to_output_folder/processed_01590.csv
# Processed and saved 01315.txt to path_to_output_folder/processed_01315.csv
# Processed and saved 01548.txt to path_to_output_folder/processed_01548.csv
# Processed and saved 01353.txt to path_to_output_folder/processed_01353.csv
# Processed and saved 01059.txt to path_to_output_folder/processed_01059.csv
# Processed and saved 00607.txt to path_to_output_folder/processed_00607.csv
# Processed and saved 00843.txt to path_to_output_folder/processed_00843.csv
# Processed and saved 00669.txt to path_to_output_folder/processed_00669.csv
# Processed and saved 00744.txt to path_to_output_folder/processed_00744.csv
# Processed and saved 00130.txt to path_to_output_folder/processed_00130.csv
# Processed and saved 00530.txt to path_to_output_folder/processed_00530.csv
# Processed and saved 00339.txt to path_to_output_folder/processed_00339.csv
# Processed and saved 01613.txt to path_to_output_folder/processed_01613.csv
# Processed and saved 00928.txt to path_to_output_folder/processed_00928.csv
# Processed and saved 00233.txt to path_to_output_folder/processed_00233.csv
# Processed and saved 01898.txt to path_to_output_folder/processed_01898.csv
# Processed and saved 01914.txt to path_to_output_folder/processed_01914.csv
# Processed and saved 01959.txt to path_to_output_folder/processed_01959.csv
# Processed and saved 00697.txt to path_to_output_folder/processed_00697.csv
# Processed and saved 01124.txt to path_to_output_folder/processed_01124.csv
# Processed and saved 01056.txt to path_to_output_folder/processed_01056.csv
# Processed and saved 01645.txt to path_to_output_folder/processed_01645.csv
# Processed and saved 01515.txt to path_to_output_folder/processed_01515.csv
# Processed and saved 01654.txt to path_to_output_folder/processed_01654.csv
# Processed and saved 00174.txt to path_to_output_folder/processed_00174.csv
# Processed and saved 00513.txt to path_to_output_folder/processed_00513.csv
# Processed and saved 01393.txt to path_to_output_folder/processed_01393.csv
# Processed and saved 01647.txt to path_to_output_folder/processed_01647.csv
# Processed and saved 01811.txt to path_to_output_folder/processed_01811.csv
# Processed and saved 00056.txt to path_to_output_folder/processed_00056.csv
# Processed and saved 01522.txt to path_to_output_folder/processed_01522.csv
# Processed and saved 00577.txt to path_to_output_folder/processed_00577.csv
# Processed and saved 01259.txt to path_to_output_folder/processed_01259.csv
# Processed and saved 00302.txt to path_to_output_folder/processed_00302.csv
# Processed and saved 00303.txt to path_to_output_folder/processed_00303.csv
# Processed and saved 01302.txt to path_to_output_folder/processed_01302.csv
# Processed and saved 00873.txt to path_to_output_folder/processed_00873.csv
# Processed and saved 00262.txt to path_to_output_folder/processed_00262.csv
# Processed and saved 01834.txt to path_to_output_folder/processed_01834.csv
# Processed and saved 01272.txt to path_to_output_folder/processed_01272.csv
# Processed and saved 00408.txt to path_to_output_folder/processed_00408.csv
# Processed and saved 00904.txt to path_to_output_folder/processed_00904.csv
# Processed and saved 01165.txt to path_to_output_folder/processed_01165.csv
# Processed and saved 00839.txt to path_to_output_folder/processed_00839.csv
# Processed and saved 01287.txt to path_to_output_folder/processed_01287.csv
# Processed and saved 00033.txt to path_to_output_folder/processed_00033.csv
# Processed and saved 01360.txt to path_to_output_folder/processed_01360.csv
# Processed and saved 00632.txt to path_to_output_folder/processed_00632.csv
# Processed and saved 00003.txt to path_to_output_folder/processed_00003.csv
# Processed and saved 00128.txt to path_to_output_folder/processed_00128.csv
# Processed and saved 01176.txt to path_to_output_folder/processed_01176.csv
# Processed and saved 01309.txt to path_to_output_folder/processed_01309.csv
# Processed and saved 01041.txt to path_to_output_folder/processed_01041.csv
# Processed and saved 00322.txt to path_to_output_folder/processed_00322.csv
# Processed and saved 01387.txt to path_to_output_folder/processed_01387.csv
# Processed and saved 01076.txt to path_to_output_folder/processed_01076.csv
# Processed and saved 01662.txt to path_to_output_folder/processed_01662.csv
# Processed and saved 00694.txt to path_to_output_folder/processed_00694.csv
# Processed and saved 01157.txt to path_to_output_folder/processed_01157.csv
# Processed and saved 00793.txt to path_to_output_folder/processed_00793.csv
# Processed and saved 01489.txt to path_to_output_folder/processed_01489.csv
# Processed and saved 01116.txt to path_to_output_folder/processed_01116.csv
# Processed and saved 01513.txt to path_to_output_folder/processed_01513.csv
# Processed and saved 00972.txt to path_to_output_folder/processed_00972.csv
# Processed and saved 00144.txt to path_to_output_folder/processed_00144.csv
# Processed and saved 00771.txt to path_to_output_folder/processed_00771.csv
# Processed and saved 00849.txt to path_to_output_folder/processed_00849.csv
# Processed and saved 00619.txt to path_to_output_folder/processed_00619.csv
# Processed and saved 01291.txt to path_to_output_folder/processed_01291.csv
# Processed and saved 01264.txt to path_to_output_folder/processed_01264.csv
# Processed and saved 00333.txt to path_to_output_folder/processed_00333.csv
# Processed and saved 00244.txt to path_to_output_folder/processed_00244.csv
# Processed and saved 00374.txt to path_to_output_folder/processed_00374.csv
# Processed and saved 00365.txt to path_to_output_folder/processed_00365.csv
# Processed and saved 01556.txt to path_to_output_folder/processed_01556.csv
# Processed and saved 00175.txt to path_to_output_folder/processed_00175.csv
# Processed and saved 01275.txt to path_to_output_folder/processed_01275.csv
# Processed and saved 00690.txt to path_to_output_folder/processed_00690.csv
# Processed and saved 01191.txt to path_to_output_folder/processed_01191.csv
# Processed and saved 01199.txt to path_to_output_folder/processed_01199.csv
# Processed and saved 01415.txt to path_to_output_folder/processed_01415.csv
# Processed and saved 00154.txt to path_to_output_folder/processed_00154.csv
# Processed and saved 00486.txt to path_to_output_folder/processed_00486.csv
# Processed and saved 01134.txt to path_to_output_folder/processed_01134.csv
# Processed and saved 00153.txt to path_to_output_folder/processed_00153.csv
# Processed and saved 00069.txt to path_to_output_folder/processed_00069.csv
# Processed and saved 00838.txt to path_to_output_folder/processed_00838.csv
# Processed and saved 01143.txt to path_to_output_folder/processed_01143.csv
# Processed and saved 00254.txt to path_to_output_folder/processed_00254.csv
# Processed and saved 00063.txt to path_to_output_folder/processed_00063.csv
# Processed and saved 00789.txt to path_to_output_folder/processed_00789.csv
# Processed and saved 00442.txt to path_to_output_folder/processed_00442.csv
# Processed and saved 01936.txt to path_to_output_folder/processed_01936.csv
# Processed and saved 00796.txt to path_to_output_folder/processed_00796.csv
# Processed and saved 01419.txt to path_to_output_folder/processed_01419.csv
# Processed and saved 00732.txt to path_to_output_folder/processed_00732.csv
# Processed and saved 00642.txt to path_to_output_folder/processed_00642.csv
# Processed and saved 00981.txt to path_to_output_folder/processed_00981.csv
# Processed and saved 01448.txt to path_to_output_folder/processed_01448.csv
# Processed and saved 01939.txt to path_to_output_folder/processed_01939.csv
# Processed and saved 01521.txt to path_to_output_folder/processed_01521.csv
# Processed and saved 00721.txt to path_to_output_folder/processed_00721.csv
# Processed and saved 00860.txt to path_to_output_folder/processed_00860.csv
# Processed and saved 00652.txt to path_to_output_folder/processed_00652.csv
# Processed and saved 01825.txt to path_to_output_folder/processed_01825.csv
# Processed and saved 01328.txt to path_to_output_folder/processed_01328.csv
# Processed and saved 01576.txt to path_to_output_folder/processed_01576.csv
# Processed and saved 01468.txt to path_to_output_folder/processed_01468.csv
# Processed and saved 00737.txt to path_to_output_folder/processed_00737.csv
# Processed and saved 01677.txt to path_to_output_folder/processed_01677.csv
# Processed and saved 01105.txt to path_to_output_folder/processed_01105.csv
# Processed and saved 01781.txt to path_to_output_folder/processed_01781.csv
# Processed and saved 01170.txt to path_to_output_folder/processed_01170.csv
# Processed and saved 01693.txt to path_to_output_folder/processed_01693.csv
# Processed and saved 00361.txt to path_to_output_folder/processed_00361.csv
# Processed and saved 00598.txt to path_to_output_folder/processed_00598.csv
# Processed and saved 01139.txt to path_to_output_folder/processed_01139.csv
# Processed and saved 00331.txt to path_to_output_folder/processed_00331.csv
# Processed and saved 01623.txt to path_to_output_folder/processed_01623.csv
# Processed and saved 00391.txt to path_to_output_folder/processed_00391.csv
# Processed and saved 00271.txt to path_to_output_folder/processed_00271.csv
# Processed and saved 00337.txt to path_to_output_folder/processed_00337.csv
# Processed and saved 01108.txt to path_to_output_folder/processed_01108.csv
# Processed and saved 01943.txt to path_to_output_folder/processed_01943.csv
# Processed and saved 01713.txt to path_to_output_folder/processed_01713.csv
# Processed and saved 01904.txt to path_to_output_folder/processed_01904.csv
# Processed and saved 00376.txt to path_to_output_folder/processed_00376.csv
# Processed and saved 01304.txt to path_to_output_folder/processed_01304.csv
# Processed and saved 01286.txt to path_to_output_folder/processed_01286.csv
# Processed and saved 00306.txt to path_to_output_folder/processed_00306.csv
# Processed and saved 01618.txt to path_to_output_folder/processed_01618.csv
# Processed and saved 01960.txt to path_to_output_folder/processed_01960.csv
# Processed and saved 01310.txt to path_to_output_folder/processed_01310.csv
# Processed and saved 00677.txt to path_to_output_folder/processed_00677.csv
# Processed and saved 00766.txt to path_to_output_folder/processed_00766.csv
# Processed and saved 01216.txt to path_to_output_folder/processed_01216.csv
# Processed and saved 00594.txt to path_to_output_folder/processed_00594.csv
# Processed and saved 01047.txt to path_to_output_folder/processed_01047.csv
# Processed and saved 00560.txt to path_to_output_folder/processed_00560.csv
# Processed and saved 01883.txt to path_to_output_folder/processed_01883.csv
# Processed and saved 00113.txt to path_to_output_folder/processed_00113.csv
# Processed and saved 01905 (1).txt to path_to_output_folder/processed_01905 (1).csv
# Processed and saved 01785.txt to path_to_output_folder/processed_01785.csv
# Processed and saved 01030.txt to path_to_output_folder/processed_01030.csv
# Processed and saved 00954.txt to path_to_output_folder/processed_00954.csv
# Processed and saved 00650.txt to path_to_output_folder/processed_00650.csv
# Processed and saved 01902.txt to path_to_output_folder/processed_01902.csv
# Processed and saved 00164.txt to path_to_output_folder/processed_00164.csv
# Processed and saved 01152.txt to path_to_output_folder/processed_01152.csv
# Processed and saved 01857.txt to path_to_output_folder/processed_01857.csv
# Processed and saved 00959.txt to path_to_output_folder/processed_00959.csv
# Processed and saved 00666.txt to path_to_output_folder/processed_00666.csv
# Processed and saved 00199.txt to path_to_output_folder/processed_00199.csv
# Processed and saved 01478.txt to path_to_output_folder/processed_01478.csv
# Processed and saved 01558.txt to path_to_output_folder/processed_01558.csv
# Processed and saved 01301.txt to path_to_output_folder/processed_01301.csv
# Processed and saved 00834.txt to path_to_output_folder/processed_00834.csv
# Processed and saved 00432.txt to path_to_output_folder/processed_00432.csv
# Processed and saved 00664.txt to path_to_output_folder/processed_00664.csv
# Processed and saved 00449.txt to path_to_output_folder/processed_00449.csv
# Processed and saved 01228.txt to path_to_output_folder/processed_01228.csv
# Processed and saved 00736.txt to path_to_output_folder/processed_00736.csv
# Processed and saved 00065.txt to path_to_output_folder/processed_00065.csv
# Processed and saved 01159.txt to path_to_output_folder/processed_01159.csv
# Processed and saved 00379.txt to path_to_output_folder/processed_00379.csv
# Processed and saved 01081.txt to path_to_output_folder/processed_01081.csv
# Processed and saved 01663.txt to path_to_output_folder/processed_01663.csv
# Processed and saved 01850.txt to path_to_output_folder/processed_01850.csv
# Processed and saved 00021.txt to path_to_output_folder/processed_00021.csv
# Processed and saved 00158.txt to path_to_output_folder/processed_00158.csv
# Processed and saved 01502.txt to path_to_output_folder/processed_01502.csv
# Processed and saved 00774.txt to path_to_output_folder/processed_00774.csv
# Processed and saved 01641.txt to path_to_output_folder/processed_01641.csv
# Processed and saved 00799.txt to path_to_output_folder/processed_00799.csv
# Processed and saved 01853.txt to path_to_output_folder/processed_01853.csv
# Processed and saved 00094.txt to path_to_output_folder/processed_00094.csv
# Processed and saved 00178.txt to path_to_output_folder/processed_00178.csv
# Processed and saved 01924.txt to path_to_output_folder/processed_01924.csv
# Processed and saved 01023.txt to path_to_output_folder/processed_01023.csv
# Processed and saved 01269.txt to path_to_output_folder/processed_01269.csv
# Processed and saved 00788.txt to path_to_output_folder/processed_00788.csv
# Processed and saved 01338.txt to path_to_output_folder/processed_01338.csv
# Processed and saved 01708.txt to path_to_output_folder/processed_01708.csv
# Processed and saved 01552.txt to path_to_output_folder/processed_01552.csv
# Processed and saved 01601.txt to path_to_output_folder/processed_01601.csv
# ...
# Processed and saved 01474.txt to path_to_output_folder/processed_01474.csv
# Processed and saved 01714.txt to path_to_output_folder/processed_01714.csv
# Processed and saved 00172.txt to path_to_output_folder/processed_00172.csv
# Processed and saved 00841.txt to path_to_output_folder/processed_00841.csv
# Processed and saved 00006.txt to path_to_output_folder/processed_00006.csv
# Processed and saved 00135.txt to path_to_output_folder/processed_00135.csv
# Processed and saved 01699.txt to path_to_output_folder/processed_01699.csv
# Processed and saved 01257.txt to path_to_output_folder/processed_01257.csv
# Processed and saved 01764.txt to path_to_output_folder/processed_01764.csv
# Processed and saved 01858.txt to path_to_output_folder/processed_01858.csv
# Processed and saved 00162.txt to path_to_output_folder/processed_00162.csv
# Processed and saved 01746.txt to path_to_output_folder/processed_01746.csv
# Processed and saved 00909.txt to path_to_output_folder/processed_00909.csv
# Processed and saved 01107.txt to path_to_output_folder/processed_01107.csv
# Processed and saved 00629.txt to path_to_output_folder/processed_00629.csv
# Processed and saved 01347.txt to path_to_output_folder/processed_01347.csv
# Processed and saved 01533.txt to path_to_output_folder/processed_01533.csv
# Processed and saved 00406.txt to path_to_output_folder/processed_00406.csv
# Processed and saved 00210.txt to path_to_output_folder/processed_00210.csv
# Processed and saved 00028.txt to path_to_output_folder/processed_00028.csv
# Processed and saved 00949.txt to path_to_output_folder/processed_00949.csv
# Processed and saved 01651.txt to path_to_output_folder/processed_01651.csv
# Processed and saved 00599.txt to path_to_output_folder/processed_00599.csv
# Processed and saved 00606.txt to path_to_output_folder/processed_00606.csv
# Processed and saved 01906 (1).txt to path_to_output_folder/processed_01906 (1).csv
# Processed and saved 01524.txt to path_to_output_folder/processed_01524.csv
# Processed and saved 00810.txt to path_to_output_folder/processed_00810.csv
# Processed and saved 01640.txt to path_to_output_folder/processed_01640.csv
# Processed and saved 00718.txt to path_to_output_folder/processed_00718.csv
# Processed and saved 01190.txt to path_to_output_folder/processed_01190.csv
# Processed and saved 01537.txt to path_to_output_folder/processed_01537.csv
# Processed and saved 00487.txt to path_to_output_folder/processed_00487.csv
# Processed and saved 00042.txt to path_to_output_folder/processed_00042.csv
# Processed and saved 00548.txt to path_to_output_folder/processed_00548.csv
# Processed and saved 01822.txt to path_to_output_folder/processed_01822.csv
# Processed and saved 00585.txt to path_to_output_folder/processed_00585.csv
# Processed and saved 00349.txt to path_to_output_folder/processed_00349.csv
# Processed and saved 00100.txt to path_to_output_folder/processed_00100.csv
# Processed and saved 00025.txt to path_to_output_folder/processed_00025.csv
# Processed and saved 01330.txt to path_to_output_folder/processed_01330.csv
# Processed and saved 00426.txt to path_to_output_folder/processed_00426.csv
# Processed and saved 00330.txt to path_to_output_folder/processed_00330.csv
# Processed and saved 00259.txt to path_to_output_folder/processed_00259.csv
# Processed and saved 01946.txt to path_to_output_folder/processed_01946.csv
# Processed and saved 01451.txt to path_to_output_folder/processed_01451.csv
# Processed and saved 00089.txt to path_to_output_folder/processed_00089.csv
# Processed and saved 00861.txt to path_to_output_folder/processed_00861.csv
# Processed and saved 01280.txt to path_to_output_folder/processed_01280.csv
# Processed and saved 01348.txt to path_to_output_folder/processed_01348.csv
# Processed and saved 00640.txt to path_to_output_folder/processed_00640.csv
# Processed and saved 00418.txt to path_to_output_folder/processed_00418.csv
# Processed and saved 00988.txt to path_to_output_folder/processed_00988.csv
# Processed and saved 01385.txt to path_to_output_folder/processed_01385.csv
# Processed and saved 00246.txt to path_to_output_folder/processed_00246.csv
# Processed and saved 01852.txt to path_to_output_folder/processed_01852.csv
# Processed and saved 01837.txt to path_to_output_folder/processed_01837.csv
# Processed and saved 01356.txt to path_to_output_folder/processed_01356.csv
# Processed and saved 00999.txt to path_to_output_folder/processed_00999.csv
# Processed and saved 00421.txt to path_to_output_folder/processed_00421.csv
# Processed and saved 00812.txt to path_to_output_folder/processed_00812.csv
# Processed and saved 00803.txt to path_to_output_folder/processed_00803.csv
# Processed and saved 00819.txt to path_to_output_folder/processed_00819.csv
# Processed and saved 00590.txt to path_to_output_folder/processed_00590.csv
# Processed and saved 00618.txt to path_to_output_folder/processed_00618.csv
# Processed and saved 01847.txt to path_to_output_folder/processed_01847.csv
# Processed and saved 00570.txt to path_to_output_folder/processed_00570.csv
# Processed and saved 00892.txt to path_to_output_folder/processed_00892.csv
# Processed and saved 01297.txt to path_to_output_folder/processed_01297.csv
# Processed and saved 00076.txt to path_to_output_folder/processed_00076.csv
# Processed and saved 01517.txt to path_to_output_folder/processed_01517.csv
# Processed and saved 01855.txt to path_to_output_folder/processed_01855.csv
# Processed and saved 01635.txt to path_to_output_folder/processed_01635.csv
# Processed and saved 01775.txt to path_to_output_folder/processed_01775.csv
# Processed and saved 00631.txt to path_to_output_folder/processed_00631.csv
# Processed and saved 00540.txt to path_to_output_folder/processed_00540.csv
# Processed and saved 00323.txt to path_to_output_folder/processed_00323.csv
# Processed and saved 00776.txt to path_to_output_folder/processed_00776.csv
# Processed and saved 00010.txt to path_to_output_folder/processed_00010.csv
# Processed and saved 00165.txt to path_to_output_folder/processed_00165.csv
# Processed and saved 01798.txt to path_to_output_folder/processed_01798.csv
# Processed and saved 00437.txt to path_to_output_folder/processed_00437.csv
# Processed and saved 01747.txt to path_to_output_folder/processed_01747.csv
# Processed and saved 00961.txt to path_to_output_folder/processed_00961.csv
# Processed and saved 00876.txt to path_to_output_folder/processed_00876.csv
# Processed and saved 00852.txt to path_to_output_folder/processed_00852.csv
# Processed and saved 01710.txt to path_to_output_folder/processed_01710.csv
# Processed and saved 01687.txt to path_to_output_folder/processed_01687.csv
# Processed and saved 01051.txt to path_to_output_folder/processed_01051.csv
# Processed and saved 00940.txt to path_to_output_folder/processed_00940.csv
# Processed and saved 01496.txt to path_to_output_folder/processed_01496.csv
# Processed and saved 00412.txt to path_to_output_folder/processed_00412.csv
# Processed and saved 00659.txt to path_to_output_folder/processed_00659.csv
# Processed and saved 01643.txt to path_to_output_folder/processed_01643.csv
# Processed and saved 00441.txt to path_to_output_folder/processed_00441.csv
# Processed and saved 00084.txt to path_to_output_folder/processed_00084.csv
# Processed and saved 01737.txt to path_to_output_folder/processed_01737.csv
# Processed and saved 00358.txt to path_to_output_folder/processed_00358.csv
# Processed and saved 01456.txt to path_to_output_folder/processed_01456.csv
# Processed and saved 00960.txt to path_to_output_folder/processed_00960.csv
# Processed and saved 01399.txt to path_to_output_folder/processed_01399.csv
# Processed and saved 01078.txt to path_to_output_folder/processed_01078.csv
# Processed and saved 01779.txt to path_to_output_folder/processed_01779.csv
# Processed and saved 00720.txt to path_to_output_folder/processed_00720.csv
# Processed and saved 00906.txt to path_to_output_folder/processed_00906.csv
# Processed and saved 01704.txt to path_to_output_folder/processed_01704.csv
# Processed and saved 01158.txt to path_to_output_folder/processed_01158.csv
# Processed and saved 00851.txt to path_to_output_folder/processed_00851.csv
# Processed and saved 00914.txt to path_to_output_folder/processed_00914.csv
# Processed and saved 00265.txt to path_to_output_folder/processed_00265.csv
# Processed and saved 00628.txt to path_to_output_folder/processed_00628.csv
# Processed and saved 01789.txt to path_to_output_folder/processed_01789.csv
# Processed and saved 00869.txt to path_to_output_folder/processed_00869.csv
# Processed and saved 00031.txt to path_to_output_folder/processed_00031.csv
# Processed and saved 00499.txt to path_to_output_folder/processed_00499.csv
# Processed and saved 01893.txt to path_to_output_folder/processed_01893.csv
# Processed and saved 00925.txt to path_to_output_folder/processed_00925.csv
# Processed and saved 01455.txt to path_to_output_folder/processed_01455.csv
# Processed and saved 00264.txt to path_to_output_folder/processed_00264.csv
# Processed and saved 01587.txt to path_to_output_folder/processed_01587.csv
# Processed and saved 01929.txt to path_to_output_folder/processed_01929.csv
# Processed and saved 01382.txt to path_to_output_folder/processed_01382.csv
# Processed and saved 00919.txt to path_to_output_folder/processed_00919.csv
# Processed and saved 00095.txt to path_to_output_folder/processed_00095.csv
# Processed and saved 00962.txt to path_to_output_folder/processed_00962.csv
# Processed and saved 01079.txt to path_to_output_folder/processed_01079.csv
# Processed and saved 00992.txt to path_to_output_folder/processed_00992.csv
# Processed and saved 00191.txt to path_to_output_folder/processed_00191.csv
# Processed and saved 01780.txt to path_to_output_folder/processed_01780.csv
# Processed and saved 01049.txt to path_to_output_folder/processed_01049.csv
# Processed and saved 01462.txt to path_to_output_folder/processed_01462.csv
# Processed and saved 01763.txt to path_to_output_folder/processed_01763.csv
# Processed and saved 00965.txt to path_to_output_folder/processed_00965.csv
# Processed and saved 01460.txt to path_to_output_folder/processed_01460.csv
# Processed and saved 01445.txt to path_to_output_folder/processed_01445.csv
# Processed and saved 00136.txt to path_to_output_folder/processed_00136.csv
# Processed and saved 00383.txt to path_to_output_folder/processed_00383.csv
# Processed and saved 00805.txt to path_to_output_folder/processed_00805.csv
# Processed and saved 01281.txt to path_to_output_folder/processed_01281.csv
# Processed and saved 00696.txt to path_to_output_folder/processed_00696.csv
# Processed and saved 00985.txt to path_to_output_folder/processed_00985.csv
# Processed and saved 01067.txt to path_to_output_folder/processed_01067.csv
# Processed and saved 01194.txt to path_to_output_folder/processed_01194.csv
# Processed and saved 01293.txt to path_to_output_folder/processed_01293.csv
# Processed and saved 01032.txt to path_to_output_folder/processed_01032.csv
# Processed and saved 01722.txt to path_to_output_folder/processed_01722.csv
# Processed and saved 01626.txt to path_to_output_folder/processed_01626.csv
# Processed and saved 01237.txt to path_to_output_folder/processed_01237.csv
# Processed and saved 00905.txt to path_to_output_folder/processed_00905.csv
# Processed and saved 01001.txt to path_to_output_folder/processed_01001.csv
# Processed and saved 00627.txt to path_to_output_folder/processed_00627.csv
# Processed and saved 00092.txt to path_to_output_folder/processed_00092.csv
# Processed and saved 00085.txt to path_to_output_folder/processed_00085.csv
# Processed and saved 01185.txt to path_to_output_folder/processed_01185.csv
# Processed and saved 01230.txt to path_to_output_folder/processed_01230.csv
# Processed and saved 01408.txt to path_to_output_folder/processed_01408.csv
# Processed and saved 01164.txt to path_to_output_folder/processed_01164.csv
# Processed and saved 01475.txt to path_to_output_folder/processed_01475.csv
# Processed and saved 01046.txt to path_to_output_folder/processed_01046.csv
# Processed and saved 01200.txt to path_to_output_folder/processed_01200.csv
# Processed and saved 00469.txt to path_to_output_folder/processed_00469.csv
# Processed and saved 00400.txt to path_to_output_folder/processed_00400.csv
# Processed and saved 00300.txt to path_to_output_folder/processed_00300.csv
# Processed and saved 01920.txt to path_to_output_folder/processed_01920.csv
# Processed and saved 00247.txt to path_to_output_folder/processed_00247.csv
# Processed and saved 00896.txt to path_to_output_folder/processed_00896.csv
# Processed and saved 01609.txt to path_to_output_folder/processed_01609.csv
# Processed and saved 00186.txt to path_to_output_folder/processed_00186.csv
# Processed and saved 01012.txt to path_to_output_folder/processed_01012.csv
# Processed and saved 00661.txt to path_to_output_folder/processed_00661.csv
# Processed and saved 00647.txt to path_to_output_folder/processed_00647.csv
# Processed and saved 00675.txt to path_to_output_folder/processed_00675.csv
# Processed and saved 00091.txt to path_to_output_folder/processed_00091.csv
# Processed and saved 00134.txt to path_to_output_folder/processed_00134.csv
# Processed and saved 00833.txt to path_to_output_folder/processed_00833.csv
# Processed and saved 01383.txt to path_to_output_folder/processed_01383.csv
# Processed and saved 00189.txt to path_to_output_folder/processed_00189.csv
# Processed and saved 00868.txt to path_to_output_folder/processed_00868.csv
# Processed and saved 00580.txt to path_to_output_folder/processed_00580.csv
# Processed and saved 01373.txt to path_to_output_folder/processed_01373.csv
# Processed and saved 01266.txt to path_to_output_folder/processed_01266.csv
# Processed and saved 01844.txt to path_to_output_folder/processed_01844.csv
# Processed and saved 01102.txt to path_to_output_folder/processed_01102.csv
# Processed and saved 00600.txt to path_to_output_folder/processed_00600.csv
# Processed and saved 01458.txt to path_to_output_folder/processed_01458.csv
# Processed and saved 00427.txt to path_to_output_folder/processed_00427.csv
# Processed and saved 00958.txt to path_to_output_folder/processed_00958.csv
# Processed and saved 00248.txt to path_to_output_folder/processed_00248.csv
# Processed and saved 00471.txt to path_to_output_folder/processed_00471.csv
# Processed and saved 00836.txt to path_to_output_folder/processed_00836.csv
# Processed and saved 01303.txt to path_to_output_folder/processed_01303.csv
# Processed and saved 01351.txt to path_to_output_folder/processed_01351.csv
# Processed and saved 00936.txt to path_to_output_folder/processed_00936.csv
# Processed and saved 01863.txt to path_to_output_folder/processed_01863.csv
# Processed and saved 00433.txt to path_to_output_folder/processed_00433.csv
# Processed and saved 00250.txt to path_to_output_folder/processed_00250.csv
# Processed and saved 01215.txt to path_to_output_folder/processed_01215.csv
# Processed and saved 01932.txt to path_to_output_folder/processed_01932.csv
# Processed and saved 00657.txt to path_to_output_folder/processed_00657.csv
# Processed and saved 01437.txt to path_to_output_folder/processed_01437.csv
# Processed and saved 01314.txt to path_to_output_folder/processed_01314.csv
# Processed and saved 01470.txt to path_to_output_folder/processed_01470.csv
# Processed and saved 01917.txt to path_to_output_folder/processed_01917.csv
# Processed and saved 00820.txt to path_to_output_folder/processed_00820.csv
# Processed and saved 01491.txt to path_to_output_folder/processed_01491.csv
# Processed and saved 01845.txt to path_to_output_folder/processed_01845.csv
# Processed and saved 01267.txt to path_to_output_folder/processed_01267.csv
# Processed and saved 00280.txt to path_to_output_folder/processed_00280.csv
# Processed and saved 01668.txt to path_to_output_folder/processed_01668.csv
# Processed and saved 01717.txt to path_to_output_folder/processed_01717.csv
# Processed and saved 00655.txt to path_to_output_folder/processed_00655.csv
# Processed and saved 01818.txt to path_to_output_folder/processed_01818.csv
# Processed and saved 01933.txt to path_to_output_folder/processed_01933.csv
# Processed and saved 00382.txt to path_to_output_folder/processed_00382.csv

# %%
import os
import pandas as pd

# Directory containing the processed CSV files
input_folder_path = 'path_to_output_folder'
combined_output_file_path = 'combined_data.csv'

# Column names
column_names = ['centroid_x', 'centroid_y', 'meanVelocity', 'length', 'width', 'density', 'rcsEq', 'rcsStd', 'track_id', 'label']

# Initialize an empty list to hold DataFrames
dataframes = []

# Loop through all files in the directory
for file_name in os.listdir(input_folder_path):
    if file_name.endswith('.csv'):  # Process only .csv files
        file_path = os.path.join(input_folder_path, file_name)

        df = pd.read_csv(file_path)

        df = df.reindex(columns=column_names)
        df['filename'] = file_name
        # Append to the list of DataFrames
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv(combined_output_file_path, index=False)

print(f"Combined data saved to {combined_output_file_path}")
# Out:
# Combined data saved to combined_data.csv

# %%
import pandas as pd

# Load your data
combined_file_path = '/content/combined_data.csv'
combined_df = pd.read_csv(combined_file_path)

# Check if DataFrame is empty
if combined_df.empty:
    print("The DataFrame is empty.")
else:
    # Check the columns
    print("Columns in DataFrame:", combined_df.columns)


    # Directly count occurrences of each label
    if 'label' in combined_df.columns:
        print("Counts for each label:")
        label_counts = combined_df['label'].value_counts()
        print(f"Class: number of samples{label_counts}")
    else:
        print("Label column not found.")
# Out:
# Columns in DataFrame: Index(['centroid_x', 'centroid_y', 'meanVelocity', 'length', 'width',
#        'density', 'rcsEq', 'rcsStd', 'track_id', 'label', 'filename'],
#       dtype='object')
# Counts for each label:
# Class: number of sampleslabel
# 5      2436
# 100    1451
# 2      1255
# 0       430
# 1       213
# 6       160
# 4       116
# 3        88
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

def add_jitter(data, noise_level=0.01):
    """Applies jitter (random noise) to numeric data."""
    jitter = noise_level * np.random.randn(*data.shape)
    return data + jitter

# Load combined data
combined_file_path = '/content/combined_data.csv'
combined_df = pd.read_csv(combined_file_path)

# Ensure 'track_id' is treated as an integer
combined_df['track_id'] = combined_df['track_id'].astype(int)

# Exclude noise label (label == 100)
combined_df = combined_df[combined_df['label'] != 100]

# Calculate the count of each label before jittering
original_counts = combined_df['label'].value_counts()
print(f"Original counts before jittering:\n{original_counts}")

# Set target count for minor classes
target_count = max(label_counts)
minor_classes = original_counts[original_counts < target_count].index.tolist()

# Track the number of jittered samples generated
jittered_counts = {label: 0 for label in minor_classes}
oversampled_data = combined_df.copy()

for minor_class in minor_classes:
    class_data = combined_df[combined_df['label'] == minor_class]
    num_samples_needed = target_count - len(class_data)

    while num_samples_needed > 0:
        # Add jitter to all numeric features except 'track_id'
        jittered_samples = class_data.copy()
        for column in class_data.columns:
            if column != 'track_id' and column != 'label':
                if pd.api.types.is_numeric_dtype(class_data[column]):
                    jittered_samples[column] = add_jitter(class_data[column].to_numpy(), noise_level=0.01)

        # Increment 'track_id' to ensure unique values
        jittered_samples['track_id'] += 1000

        # Limit the jittered samples to the exact number needed
        num_to_add = min(num_samples_needed, len(class_data))
        jittered_samples = jittered_samples.sample(n=num_to_add, replace=True)

        # Append jittered samples to the oversampled data
        oversampled_data = pd.concat([oversampled_data, jittered_samples], ignore_index=True)

        # Update the count of jittered samples
        jittered_counts[minor_class] += num_to_add
        num_samples_needed -= num_to_add

#shuffling
oversampled_data = oversampled_data.sample(frac=1, random_state=42).reset_index(drop=True)


# Save the balanced data to a new file
balanced_file_path = '/content/balanced_data.csv'
oversampled_data.to_csv(balanced_file_path, index=False)
print(f"Balanced data with jittering saved to {balanced_file_path}")

# Print jittered sample counts for each label
print("Jittered sample counts for each label:")
for label, count in jittered_counts.items():
    print(f"Label {label}: {count} samples")
# Out:
# Original counts before jittering:
# label
# 5    2436
# 2    1255
# 0     430
# 1     213
# 6     160
# 4     116
# 3      88
# Name: count, dtype: int64
# Balanced data with jittering saved to /content/balanced_data.csv
# Jittered sample counts for each label:
# Label 2: 1181 samples
# Label 0: 2006 samples
# Label 1: 2223 samples
# Label 6: 2276 samples
# Label 4: 2320 samples
# Label 3: 2348 samples

# %%
# Load the balanced data
balanced_file_path = '/content/balanced_data.csv'
balanced_df = pd.read_csv(balanced_file_path)

# Get the total number of samples for each label
label_counts = balanced_df['label'].value_counts()
print("Total number of samples for each label after jittering:")
print(label_counts)
# Out:
# Total number of samples for each label after jittering:
# label
# 6    2436
# 3    2436
# 1    2436
# 4    2436
# 5    2436
# 2    2436
# 0    2436
# Name: count, dtype: int64

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

def plot_histograms_for_features(original_df, jittered_df, output_path):
    """
    Plot histograms for each feature in the original and jittered datasets.

    Parameters:
        original_df (pd.DataFrame): The original dataset before jittering.
        jittered_df (pd.DataFrame): The dataset after jittering.
        output_path (str): The directory path to save histogram plots.
    """
    # Create the directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)

    # List of features (columns) to plot
    features = original_df.columns

    for feature in features:
        # Only plot numeric features
        if pd.api.types.is_numeric_dtype(original_df[feature]):
            plt.figure(figsize=(12, 6))

            # Histogram of original data
            plt.subplot(1, 2, 1)
            plt.hist(original_df[feature], bins=30, edgecolor='black', alpha=0.7)
            plt.title(f'Avant Jittering - {feature}')
            plt.xlabel('Valeur')
            plt.ylabel('Fréquence')

            # Histogram of jittered data
            plt.subplot(1, 2, 2)
            plt.hist(jittered_df[feature], bins=30, edgecolor='black', alpha=0.7)
            plt.title(f'Après Jittering - {feature}')
            plt.xlabel('Valeur')
            plt.ylabel('Fréquence')

            plt.tight_layout()

            # Save the histogram
            plt_path = os.path.join(output_path, f'{feature}_histograms.png')
            plt.savefig(plt_path)
            plt.close()
            print(f"Histogramme pour {feature} sauvegardé à {plt_path}")

# Load the original and balanced datasets
original_file_path = '/content/combined_data.csv'
balanced_file_path = '/content/balanced_data.csv'

original_df = pd.read_csv(original_file_path)
df_balanced = pd.read_csv(balanced_file_path)

# Set the output path for histograms
output_histogram_path = '/content/histograms'

# Plot histograms
plot_histograms_for_features(original_df, df_balanced, output_histogram_path)
# Out:
# Histogramme pour centroid_x sauvegardé à /content/histograms/centroid_x_histograms.png
# Histogramme pour centroid_y sauvegardé à /content/histograms/centroid_y_histograms.png
# Histogramme pour meanVelocity sauvegardé à /content/histograms/meanVelocity_histograms.png
# Histogramme pour length sauvegardé à /content/histograms/length_histograms.png
# Histogramme pour width sauvegardé à /content/histograms/width_histograms.png
# Histogramme pour density sauvegardé à /content/histograms/density_histograms.png
# Histogramme pour rcsEq sauvegardé à /content/histograms/rcsEq_histograms.png
# Histogramme pour rcsStd sauvegardé à /content/histograms/rcsStd_histograms.png
# Histogramme pour track_id sauvegardé à /content/histograms/track_id_histograms.png
# Histogramme pour label sauvegardé à /content/histograms/label_histograms.png

# %%
import os
import pandas as pd
import random

# Define folder paths
folder_path = '/content/drive/MyDrive/Testing_data'  # Directory containing the .txt files
output_folder_path = '/content/original_data_labels'  # Folder to save processed CSV files
combined_output_file_path = 'TestingData_data.csv'  # Output for combined CSV file

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Column names for the DataFrames
column_names = ['centroid_x', 'centroid_y', 'meanVelocity', 'length', 'width', 'density', 'rcsEq', 'rcsStd', 'track_id', 'label']

# Set Pandas display option to show all columns
pd.set_option('display.max_columns', None)

# List to hold individual DataFrames
dataframes = []

# Load all .txt files from the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        file_path = os.path.join(folder_path, file_name)

        # Skip and delete empty files
        if os.path.getsize(file_path) == 0:
            os.remove(file_path)
            print(f"Deleted empty file: {file_path}")
            continue

        # Read the file into a DataFrame
        df = pd.read_csv(file_path, header=None, delimiter=',')

        # Ensure the DataFrame has the correct number of columns
        if df.shape[1] < len(column_names):
            df = df.reindex(columns=range(len(column_names)))

        # Assign column names
        df.columns = column_names[:df.shape[1]]

        # Add DataFrame to the list
        dataframes.append((file_name, df))

# Shuffle the DataFrames list
random.shuffle(dataframes)

# Save each shuffled DataFrame to a new CSV file
for file_name, df in dataframes:
    # Define the output path for each processed file
    output_file_path = os.path.join(output_folder_path, f"processed_{file_name.replace('.txt', '.csv')}")
    df.to_csv(output_file_path, index=False)
    print(f"Processed and saved {file_name} to {output_file_path}")

# Now, combine all the processed CSV files
# List to hold the combined DataFrames
combined_dataframes = []

# Loop through all processed CSV files in the output folder
for file_name in os.listdir(output_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(output_folder_path, file_name)
        df = pd.read_csv(file_path)

        # Ensure correct column order and add file name as a new column
        df = df.reindex(columns=column_names)
        df['filename'] = file_name

        # Add DataFrame to the list of combined DataFrames
        combined_dataframes.append(df)

# Concatenate all individual DataFrames into one
combined_df = pd.concat(combined_dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv(combined_output_file_path, index=False)
print(f"Combined data saved to {combined_output_file_path}")
# Out:
# Processed and saved 07345.txt to /content/original_data_labels/processed_07345.csv
# Processed and saved 09880.txt to /content/original_data_labels/processed_09880.csv
# Processed and saved 07313.txt to /content/original_data_labels/processed_07313.csv
# Processed and saved 07306.txt to /content/original_data_labels/processed_07306.csv
# Processed and saved 09906.txt to /content/original_data_labels/processed_09906.csv
# Processed and saved 09903.txt to /content/original_data_labels/processed_09903.csv
# Processed and saved 09752.txt to /content/original_data_labels/processed_09752.csv
# Processed and saved 09800.txt to /content/original_data_labels/processed_09800.csv
# Processed and saved 09911.txt to /content/original_data_labels/processed_09911.csv
# Processed and saved 09777.txt to /content/original_data_labels/processed_09777.csv
# Processed and saved 09853.txt to /content/original_data_labels/processed_09853.csv
# Processed and saved 07309.txt to /content/original_data_labels/processed_07309.csv
# Processed and saved 07325.txt to /content/original_data_labels/processed_07325.csv
# Processed and saved 07300.txt to /content/original_data_labels/processed_07300.csv
# Processed and saved 09882.txt to /content/original_data_labels/processed_09882.csv
# Processed and saved 09756.txt to /content/original_data_labels/processed_09756.csv
# Processed and saved 07351.txt to /content/original_data_labels/processed_07351.csv
# Processed and saved 09867.txt to /content/original_data_labels/processed_09867.csv
# Processed and saved 09766.txt to /content/original_data_labels/processed_09766.csv
# Processed and saved 09863.txt to /content/original_data_labels/processed_09863.csv
# Processed and saved 07303.txt to /content/original_data_labels/processed_07303.csv
# Processed and saved 09923.txt to /content/original_data_labels/processed_09923.csv
# Processed and saved 09912.txt to /content/original_data_labels/processed_09912.csv
# Processed and saved 09802.txt to /content/original_data_labels/processed_09802.csv
# Processed and saved 09750.txt to /content/original_data_labels/processed_09750.csv
# Processed and saved 09929.txt to /content/original_data_labels/processed_09929.csv
# Processed and saved 09848.txt to /content/original_data_labels/processed_09848.csv
# Processed and saved 07340.txt to /content/original_data_labels/processed_07340.csv
# Processed and saved 09875.txt to /content/original_data_labels/processed_09875.csv
# Processed and saved 09864.txt to /content/original_data_labels/processed_09864.csv
# Processed and saved 07334.txt to /content/original_data_labels/processed_07334.csv
# Processed and saved 09808.txt to /content/original_data_labels/processed_09808.csv
# Processed and saved 09905.txt to /content/original_data_labels/processed_09905.csv
# Processed and saved 09856.txt to /content/original_data_labels/processed_09856.csv
# Processed and saved 07312.txt to /content/original_data_labels/processed_07312.csv
# Processed and saved 09832.txt to /content/original_data_labels/processed_09832.csv
# Processed and saved 09783.txt to /content/original_data_labels/processed_09783.csv
# Processed and saved 09885.txt to /content/original_data_labels/processed_09885.csv
# Processed and saved 07330.txt to /content/original_data_labels/processed_07330.csv
# Processed and saved 09792.txt to /content/original_data_labels/processed_09792.csv
# Processed and saved 07339.txt to /content/original_data_labels/processed_07339.csv
# Processed and saved 07318.txt to /content/original_data_labels/processed_07318.csv
# Processed and saved 09890.txt to /content/original_data_labels/processed_09890.csv
# Processed and saved 09762.txt to /content/original_data_labels/processed_09762.csv
# Processed and saved 09760.txt to /content/original_data_labels/processed_09760.csv
# Processed and saved 09879.txt to /content/original_data_labels/processed_09879.csv
# Processed and saved 07336.txt to /content/original_data_labels/processed_07336.csv
# Processed and saved 09857.txt to /content/original_data_labels/processed_09857.csv
# Processed and saved 07346.txt to /content/original_data_labels/processed_07346.csv
# Processed and saved 09801.txt to /content/original_data_labels/processed_09801.csv
# Processed and saved 07311.txt to /content/original_data_labels/processed_07311.csv
# Processed and saved 07315.txt to /content/original_data_labels/processed_07315.csv
# Processed and saved 07327.txt to /content/original_data_labels/processed_07327.csv
# Processed and saved 09773.txt to /content/original_data_labels/processed_09773.csv
# Processed and saved 07333.txt to /content/original_data_labels/processed_07333.csv
# Processed and saved 07317.txt to /content/original_data_labels/processed_07317.csv
# Processed and saved 07347.txt to /content/original_data_labels/processed_07347.csv
# Processed and saved 07342.txt to /content/original_data_labels/processed_07342.csv
# Processed and saved 09782.txt to /content/original_data_labels/processed_09782.csv
# Processed and saved 07323.txt to /content/original_data_labels/processed_07323.csv
# Processed and saved 07321.txt to /content/original_data_labels/processed_07321.csv
# Processed and saved 09930 - Copie.txt to /content/original_data_labels/processed_09930 - Copie.csv
# Processed and saved 07341.txt to /content/original_data_labels/processed_07341.csv
# Processed and saved 07299.txt to /content/original_data_labels/processed_07299.csv
# Processed and saved 09768.txt to /content/original_data_labels/processed_09768.csv
# Processed and saved 09803.txt to /content/original_data_labels/processed_09803.csv
# Processed and saved 09868.txt to /content/original_data_labels/processed_09868.csv
# Processed and saved 09916.txt to /content/original_data_labels/processed_09916.csv
# Processed and saved 09797.txt to /content/original_data_labels/processed_09797.csv
# Processed and saved 09784.txt to /content/original_data_labels/processed_09784.csv
# Processed and saved 09755.txt to /content/original_data_labels/processed_09755.csv
# Processed and saved 09871.txt to /content/original_data_labels/processed_09871.csv
# Processed and saved 09849.txt to /content/original_data_labels/processed_09849.csv
# Processed and saved 07354.txt to /content/original_data_labels/processed_07354.csv
# Processed and saved 07328.txt to /content/original_data_labels/processed_07328.csv
# Processed and saved 09855.txt to /content/original_data_labels/processed_09855.csv
# Processed and saved 09822.txt to /content/original_data_labels/processed_09822.csv
# Processed and saved 09790.txt to /content/original_data_labels/processed_09790.csv
# Processed and saved 07349.txt to /content/original_data_labels/processed_07349.csv
# Processed and saved 09769.txt to /content/original_data_labels/processed_09769.csv
# Processed and saved 09789.txt to /content/original_data_labels/processed_09789.csv
# Processed and saved 09811.txt to /content/original_data_labels/processed_09811.csv
# Processed and saved 09873.txt to /content/original_data_labels/processed_09873.csv
# Processed and saved 09860.txt to /content/original_data_labels/processed_09860.csv
# Processed and saved 07326.txt to /content/original_data_labels/processed_07326.csv
# Processed and saved 07322.txt to /content/original_data_labels/processed_07322.csv
# Processed and saved 07350.txt to /content/original_data_labels/processed_07350.csv
# Processed and saved 09862.txt to /content/original_data_labels/processed_09862.csv
# Processed and saved 09765.txt to /content/original_data_labels/processed_09765.csv
# Processed and saved 09796.txt to /content/original_data_labels/processed_09796.csv
# Processed and saved 07302.txt to /content/original_data_labels/processed_07302.csv
# Processed and saved 09902.txt to /content/original_data_labels/processed_09902.csv
# Processed and saved 09854.txt to /content/original_data_labels/processed_09854.csv
# Processed and saved 07305.txt to /content/original_data_labels/processed_07305.csv
# Processed and saved 07335.txt to /content/original_data_labels/processed_07335.csv
# Processed and saved 09924.txt to /content/original_data_labels/processed_09924.csv
# Processed and saved 07314.txt to /content/original_data_labels/processed_07314.csv
# Processed and saved 09757.txt to /content/original_data_labels/processed_09757.csv
# Processed and saved 09798.txt to /content/original_data_labels/processed_09798.csv
# Processed and saved 09804.txt to /content/original_data_labels/processed_09804.csv
# Processed and saved 09775.txt to /content/original_data_labels/processed_09775.csv
# Processed and saved 09850.txt to /content/original_data_labels/processed_09850.csv
# Processed and saved 09870.txt to /content/original_data_labels/processed_09870.csv
# Processed and saved 09781.txt to /content/original_data_labels/processed_09781.csv
# Processed and saved 07337.txt to /content/original_data_labels/processed_07337.csv
# Processed and saved 09851.txt to /content/original_data_labels/processed_09851.csv
# Processed and saved 07320.txt to /content/original_data_labels/processed_07320.csv
# Processed and saved 09844.txt to /content/original_data_labels/processed_09844.csv
# Processed and saved 09883.txt to /content/original_data_labels/processed_09883.csv
# Processed and saved 09778.txt to /content/original_data_labels/processed_09778.csv
# Processed and saved 09786.txt to /content/original_data_labels/processed_09786.csv
# Processed and saved 09774.txt to /content/original_data_labels/processed_09774.csv
# Processed and saved 09859.txt to /content/original_data_labels/processed_09859.csv
# Processed and saved 09889.txt to /content/original_data_labels/processed_09889.csv
# Processed and saved 09921.txt to /content/original_data_labels/processed_09921.csv
# Processed and saved 07358.txt to /content/original_data_labels/processed_07358.csv
# Processed and saved 09845.txt to /content/original_data_labels/processed_09845.csv
# Processed and saved 09751.txt to /content/original_data_labels/processed_09751.csv
# Processed and saved 09770.txt to /content/original_data_labels/processed_09770.csv
# Processed and saved 09795.txt to /content/original_data_labels/processed_09795.csv
# Processed and saved 09763.txt to /content/original_data_labels/processed_09763.csv
# Processed and saved 09922.txt to /content/original_data_labels/processed_09922.csv
# Processed and saved 09887.txt to /content/original_data_labels/processed_09887.csv
# Processed and saved 09884.txt to /content/original_data_labels/processed_09884.csv
# Processed and saved 09794.txt to /content/original_data_labels/processed_09794.csv
# Processed and saved 09771.txt to /content/original_data_labels/processed_09771.csv
# Processed and saved 09754.txt to /content/original_data_labels/processed_09754.csv
# Processed and saved 07310.txt to /content/original_data_labels/processed_07310.csv
# Processed and saved 09759.txt to /content/original_data_labels/processed_09759.csv
# Processed and saved 09918.txt to /content/original_data_labels/processed_09918.csv
# Processed and saved 09901.txt to /content/original_data_labels/processed_09901.csv
# Processed and saved 07331.txt to /content/original_data_labels/processed_07331.csv
# Processed and saved 07308.txt to /content/original_data_labels/processed_07308.csv
# Processed and saved 07319.txt to /content/original_data_labels/processed_07319.csv
# Processed and saved 09753.txt to /content/original_data_labels/processed_09753.csv
# Processed and saved 09791.txt to /content/original_data_labels/processed_09791.csv
# Processed and saved 09776.txt to /content/original_data_labels/processed_09776.csv
# Processed and saved 07301.txt to /content/original_data_labels/processed_07301.csv
# Processed and saved 09823.txt to /content/original_data_labels/processed_09823.csv
# Processed and saved 09926.txt to /content/original_data_labels/processed_09926.csv
# Processed and saved 07338.txt to /content/original_data_labels/processed_07338.csv
# Processed and saved 07332.txt to /content/original_data_labels/processed_07332.csv
# Processed and saved 09919.txt to /content/original_data_labels/processed_09919.csv
# Processed and saved 09928.txt to /content/original_data_labels/processed_09928.csv
# Processed and saved 09834.txt to /content/original_data_labels/processed_09834.csv
# Processed and saved 09865.txt to /content/original_data_labels/processed_09865.csv
# Processed and saved 09886.txt to /content/original_data_labels/processed_09886.csv
# Processed and saved 09847.txt to /content/original_data_labels/processed_09847.csv
# Processed and saved 09785.txt to /content/original_data_labels/processed_09785.csv
# Processed and saved 07316.txt to /content/original_data_labels/processed_07316.csv
# Processed and saved 09799.txt to /content/original_data_labels/processed_09799.csv
# Processed and saved 07355.txt to /content/original_data_labels/processed_07355.csv
# Processed and saved 09869.txt to /content/original_data_labels/processed_09869.csv
# Processed and saved 09772.txt to /content/original_data_labels/processed_09772.csv
# Processed and saved 09788.txt to /content/original_data_labels/processed_09788.csv
# Processed and saved 09925.txt to /content/original_data_labels/processed_09925.csv
# Processed and saved 09787.txt to /content/original_data_labels/processed_09787.csv
# Processed and saved 09761.txt to /content/original_data_labels/processed_09761.csv
# Processed and saved 09810.txt to /content/original_data_labels/processed_09810.csv
# Processed and saved 09812.txt to /content/original_data_labels/processed_09812.csv
# Processed and saved 09930.txt to /content/original_data_labels/processed_09930.csv
# Processed and saved 09858.txt to /content/original_data_labels/processed_09858.csv
# Processed and saved 07324.txt to /content/original_data_labels/processed_07324.csv
# Processed and saved 09767.txt to /content/original_data_labels/processed_09767.csv
# Processed and saved 09927.txt to /content/original_data_labels/processed_09927.csv
# Processed and saved 09825.txt to /content/original_data_labels/processed_09825.csv
# Processed and saved 07343.txt to /content/original_data_labels/processed_07343.csv
# Processed and saved 07352.txt to /content/original_data_labels/processed_07352.csv
# Processed and saved 09874.txt to /content/original_data_labels/processed_09874.csv
# Processed and saved 09793.txt to /content/original_data_labels/processed_09793.csv
# Processed and saved 09827.txt to /content/original_data_labels/processed_09827.csv
# Processed and saved 07353.txt to /content/original_data_labels/processed_07353.csv
# Processed and saved 09805.txt to /content/original_data_labels/processed_09805.csv
# Processed and saved 09807.txt to /content/original_data_labels/processed_09807.csv
# Processed and saved 09876.txt to /content/original_data_labels/processed_09876.csv
# Processed and saved 07357.txt to /content/original_data_labels/processed_07357.csv
# Processed and saved 09888.txt to /content/original_data_labels/processed_09888.csv
# Processed and saved 09779.txt to /content/original_data_labels/processed_09779.csv
# Processed and saved 09881.txt to /content/original_data_labels/processed_09881.csv
# Processed and saved 09861.txt to /content/original_data_labels/processed_09861.csv
# Processed and saved 09826.txt to /content/original_data_labels/processed_09826.csv
# Processed and saved 09780.txt to /content/original_data_labels/processed_09780.csv
# Processed and saved 07348.txt to /content/original_data_labels/processed_07348.csv
# Processed and saved 09852.txt to /content/original_data_labels/processed_09852.csv
# Processed and saved 09877.txt to /content/original_data_labels/processed_09877.csv
# Processed and saved 09843.txt to /content/original_data_labels/processed_09843.csv
# Processed and saved 09878.txt to /content/original_data_labels/processed_09878.csv
# Processed and saved 07304.txt to /content/original_data_labels/processed_07304.csv
# Processed and saved 09846.txt to /content/original_data_labels/processed_09846.csv
# Processed and saved 09764.txt to /content/original_data_labels/processed_09764.csv
# Processed and saved 09806.txt to /content/original_data_labels/processed_09806.csv
# Processed and saved 09917.txt to /content/original_data_labels/processed_09917.csv
# Processed and saved 07344.txt to /content/original_data_labels/processed_07344.csv
# Processed and saved 09872.txt to /content/original_data_labels/processed_09872.csv
# Processed and saved 09809.txt to /content/original_data_labels/processed_09809.csv
# Processed and saved 09891.txt to /content/original_data_labels/processed_09891.csv
# Processed and saved 07307.txt to /content/original_data_labels/processed_07307.csv
# Processed and saved 07329.txt to /content/original_data_labels/processed_07329.csv
# Processed and saved 09758.txt to /content/original_data_labels/processed_09758.csv
# Processed and saved 09920.txt to /content/original_data_labels/processed_09920.csv
# Processed and saved 09866.txt to /content/original_data_labels/processed_09866.csv
# Processed and saved 07356.txt to /content/original_data_labels/processed_07356.csv
# Combined data saved to TestingData_data.csv

# %%
import pandas as pd

# Load combined data
combined_file_path = '/content/TestingData_data.csv'
combined_df = pd.read_csv(combined_file_path)

# Ensure 'track_id' is treated as an integer
combined_df['track_id'] = combined_df['track_id'].astype(int)

# Exclude noise label (label == 100)
combined_df = combined_df[combined_df['label'] != 100]

# Define the target sample size for each label
target_sample_size = 300

# List to hold resampled data for each label
resampled_data = []

# Resample data for each label
for label in combined_df['label'].unique():
    label_data = combined_df[combined_df['label'] == label]
    if len(label_data) > target_sample_size:
        # Downsample if there are more than target samples
        label_data = label_data.sample(n=target_sample_size, random_state=42)
    elif len(label_data) < target_sample_size:
        # Upsample if there are fewer samples
        label_data = label_data.sample(n=target_sample_size, replace=True, random_state=42)
    resampled_data.append(label_data)

# Combine all resampled data into a single DataFrame
balanced_df = pd.concat(resampled_data, ignore_index=True)

# Shuffle the rows in the balanced DataFrame
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the balanced data to a new file named 'original_data_labels.csv'
balanced_file_path = '/content/original_data_labels11.csv'
balanced_df.to_csv(balanced_file_path, index=False)
print(f"Balanced data with each label having {target_sample_size} samples saved to {balanced_file_path}")

# Print the count of samples per label in the balanced dataset
print("Sample counts for each label in the balanced dataset:")
print(balanced_df['label'].value_counts())
# Out:
# Balanced data with each label having 300 samples saved to /content/original_data_labels11.csv
# Sample counts for each label in the balanced dataset:
# label
# 4    300
# 0    300
# 2    300
# 5    300
# 3    300
# Name: count, dtype: int64
